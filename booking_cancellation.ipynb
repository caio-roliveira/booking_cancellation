# %% [markdown]
# # Próximos passos
# 28/09
# - Leitura do artigo principal
# - Leitura do artigo de referência

# %% [markdown]
# # Contexto
#
# - Projeto para o time comercial
#
# ## Funções do Time Comercial
# - Gerir parcerias e descontos com os hoteleiros, de acordo com períodos do ano ou tipos de reserva;
# - Decidir quais hotéis devem ser mantidos no catálogo de produtos e quais devem ser retirados;
# - Identificar perfis de pessoas ou destinos onde existem oportunidades para focarmos esforços em buscar novos parceiros
#
# # Business Case
# Há um conjunto de dados sobre reservas passadas de hotéis, e o objetivo é:
# - Descobrir padrões úteis nos dados históricos de reservas que podem auxiliar na tomada de decisão quanto à formulação de estratégias comerciais para lidar com cancelamentos de reservas.
# - Construir um modelo capaz de prever se uma reserva será cancelada
#
# ## Contexto Mercadológico
#
# Apesar de possuirmos uma base de dados que contém histórico entre 2014 e 2017, podemos realizar uma leitura do mercado atual para entender melhor do contexto em que nos encontramos, e realizar melhores hipóteses a serem testadas.
#
# ### Viagens Domésticas
# Como pode ser visto na imagem abaixo [
# ![image.png](attachment:image.png)
#
#
#
# Além do Brasil, já estamos em mais de 4.700 cidades internacionais, contabilizando mais de 500 mil usuários registrados na plataforma. Nos anos de 2020 e 2021, nosso volume bruto de mercadorias (GMV) foi de respectivamente R$1,8bi e R$1,9bi.

# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Upload

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# # Entendimento dos Dados

# %% [markdown]
# - Conjunto de dados possui informações acerca de reservas realizadas para hotéis em cidades e resorts.
# - O conjunto de dados se trata das reservas de apenas 2 hotéis. Ambos localizados em Portugal.
#     - Resort localiza-se em Algarve
#     - Hotel da Cidade localiza-se em Lisboa.
# - Dados contém reservas com datas de check-in entre 1/7/2015 e 31/8/2017
# - Dados contém reservas que foram utilizadas de fato e que foram canceladas.
# - Não há dados pessoais que possam identificar os clientes, uma vez que se tratam de dados reais.
# -

# %%
df.reservation_status_date.max()
# Out:
# '2017-09-14'

# %%
df.country.value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# ATF        1
# MRT        1
# BHS        1
# LCA        1
# NPL        1
# Name: country, Length: 177, dtype: int64

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# # Referências
#
# 1. https://wttc.org/Portals/0/Documents/Reports/2022/EIR2022-Global%20Trends.pdf
